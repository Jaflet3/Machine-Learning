# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
cr=pd.read_csv('/content/car_price_prediction_.csv')

# %%
LR=LinearRegression()

# %%
cr.head()
# Out:
#    Car ID  Brand  Year  Engine Size Fuel Type Transmission  Mileage Condition  \
# 0       1  Tesla  2016          2.3    Petrol       Manual   114832       New
# 1       2    BMW  2018          4.4  Electric       Manual   143190      Used
# 2       3   Audi  2013          4.5  Electric       Manual   181601       New
# 3       4  Tesla  2011          4.1    Diesel    Automatic    68682       New
# 4       5   Ford  2009          2.6    Diesel       Manual   223009  Like New
#
#       Price     Model
# 0  26613.92   Model X
# 1  14679.61  5 Series
# 2  44402.61        A4
# 3  86374.33   Model Y
# 4  73577.10   Mustang

# %%
cr.isnull().sum()
# Out:
# Car ID          0
# Brand           0
# Year            0
# Engine Size     0
# Fuel Type       0
# Transmission    0
# Mileage         0
# Condition       0
# Price           0
# Model           0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
a=LabelEncoder()

# %%
b=LabelEncoder()

# %%
cr['Brand_new']=le.fit_transform(cr['Brand'])

# %%
cr['fuel_new']=a.fit_transform(cr['Fuel Type'])

# %%
cr['m_new']=le.fit_transform(cr['Model'])

# %%
cr.head()
# Out:
#    Car ID  Brand  Year  Engine Size Fuel Type Transmission  Mileage Condition  \
# 0       1  Tesla  2016          2.3    Petrol       Manual   114832       New
# 1       2    BMW  2018          4.4  Electric       Manual   143190      Used
# 2       3   Audi  2013          4.5  Electric       Manual   181601       New
# 3       4  Tesla  2011          4.1    Diesel    Automatic    68682       New
# 4       5   Ford  2009          2.6    Diesel       Manual   223009  Like New
#
#       Price     Model  Brand_new  fuel_new  m_new
# 0  26613.92   Model X          5         3     19
# 1  14679.61  5 Series          1         1      1
# 2  44402.61        A4          0         1      3
# 3  86374.33   Model Y          5         0     20
# 4  73577.10   Mustang          2         0     21

# %%
# Select columns, correcting the typo in 'fuel_new'
i = cr[['Car ID', 'Brand_new', 'Year', 'Engine Size', 'fuel_new', 'Mileage', 'm_new']]

# %%
d=cr['Price']

# %%
LR.fit(i, d)
# Out:
# LinearRegression()

# %%
LR.predict([[3,1,2019,4,1,181601,4]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([52479.57956515])
